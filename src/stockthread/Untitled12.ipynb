# %%
# -*- coding: utf-8 -*-

import pandas as pd
from sarimaxModel import forcastStocks
from loadstocks import loadStocksByTickers
from loadstocks import loadAuTickersFromYahooExcel
# We will look at stock prices over the past year, starting at January 1, 2016

path='/root/pythondev/JanePython/'
inputfile = path+'Yahoo.xlsx'
outputfile = path+'stocks10.csv'

tickers=loadAuTickersFromYahooExcel(inputfile)
tickers=tickers[2000:]
stocks=loadStocksByTickers(tickers,outputfile)
print(len(stocks))
# Out:
# RUL.AX new date:: 2017-07-06 2019-05-06 True
# SLM.AX new date:: 2017-07-06 2019-05-06 True
# SLM.AX error cannot reindex from a duplicate axis
# SBR.AX new date:: 2017-07-06 2019-05-06 True
# SBR.AX error cannot reindex from a duplicate axis
# SIE.AX new date:: 2017-07-06 2019-05-06 True
# SIE.AX error No data fetched for symbol SIE.AX using YahooDailyReader
# SCU.AX new date:: 2017-07-06 2019-05-06 True
# SDA.AX new date:: 2017-07-06 2019-05-06 True
# SDI.AX new date:: 2017-07-06 2019-05-06 True
# SSM.AX new date:: 2017-07-06 2019-05-06 True
# SFG.AX new date:: 2017-07-06 2019-05-06 True
# SFX.AX new date:: 2017-07-06 2019-05-06 True
# SGN.AX new date:: 2017-07-06 2019-05-06 True
# SGN.AX error No data fetched for symbol SGN.AX using YahooDailyReader
# SGC.AX new date:: 2017-07-06 2019-05-06 True
# SRO.AX new date:: 2017-07-06 2019-05-06 True
# SHU.AX new date:: 2017-07-06 2019-05-06 True
# SHU.AX error No data fetched for symbol SHU.AX using YahooDailyReader
# TRS.AX new date:: 2017-07-06 2019-05-06 True
# SHH.AX new date:: 2017-07-06 2019-05-06 True
# SHH.AX error No data fetched for symbol SHH.AX using YahooDailyReader
# SSL.AX new date:: 2017-07-06 2019-05-06 True
# SIX.AX new date:: 2017-07-06 2019-05-06 True
# SIX.AX error No data fetched for symbol SIX.AX using YahooDailyReader
# SVA.AX new date:: 2017-07-06 2019-05-06 True
# SVA.AX error No data fetched for symbol SVA.AX using YahooDailyReader
# SSLPA.AX new date:: 2017-07-06 2019-05-06 True
# SSLPA.AX error No data fetched for symbol SSLPA.AX using YahooDailyReader
# SKF.AX new date:: 2017-07-06 2019-05-06 True
# SKIKOQ-A new date:: 2017-07-06 2019-05-06 True
# SKIKOQ-A error No data fetched for symbol SKIKOQ-A using YahooDailyReader
# SLC.AX new date:: 2017-07-06 2019-05-06 True
# SLA.AX new date:: 2017-07-06 2019-05-06 True
# SLA.AX error No data fetched for symbol SLA.AX using YahooDailyReader
# SMG.AX new date:: 2017-07-06 2019-05-06 True
# SMG.AX error No data fetched for symbol SMG.AX using YahooDailyReader
# SMR.AX new date:: 2017-07-06 2019-05-06 True
# SNY.AX new date:: 2017-07-06 2019-05-06 True
# SNY.AX error No data fetched for symbol SNY.AX using YahooDailyReader
# SOM.AX new date:: 2017-07-06 2019-05-06 True
# SOM.AX error cannot reindex from a duplicate axis
# SVM.AX new date:: 2017-07-06 2019-05-06 True
# SRT.AX new date:: 2017-07-06 2019-05-06 True
# SRT.AX error No data fetched for symbol SRT.AX using YahooDailyReader
# SRZ.AX new date:: 2017-07-06 2019-05-06 True
# SRS.AX new date:: 2017-07-06 2019-05-06 True
# SRQDA.AX new date:: 2017-07-06 2019-05-06 True
# SRQDA.AX error No data fetched for symbol SRQDA.AX using YahooDailyReader
# STS.AX new date:: 2017-07-06 2019-05-06 True
# STS.AX error No data fetched for symbol STS.AX using YahooDailyReader
# SRH.AX new date:: 2017-07-06 2019-05-06 True
# SRY.AX new date:: 2017-07-06 2019-05-06 True
# STOKRN-A new date:: 2017-07-06 2019-05-06 True
# STOKRN-A error No data fetched for symbol STOKRN-A using YahooDailyReader
# SWJ.AX new date:: 2017-07-06 2019-05-06 True
# SWJ.AX error No data fetched for symbol SWJ.AX using YahooDailyReader
# SPQ.AX new date:: 2017-07-06 2019-05-06 True
# SUNCD.AX new date:: 2017-07-06 2019-05-06 True
# SUNCD.AX error No data fetched for symbol SUNCD.AX using YahooDailyReader
# SUL.AX new date:: 2017-07-06 2019-05-06 True
# SVS.AX new date:: 2017-07-06 2019-05-06 True
# SOI.AX new date:: 2017-07-06 2019-05-06 True
# SOI.AX error No data fetched for symbol SOI.AX using YahooDailyReader
# SOIDA.AX new date:: 2017-07-06 2019-05-06 True
# SOIDA.AX error No data fetched for symbol SOIDA.AX using YahooDailyReader
# SWMKOB-A new date:: 2017-07-06 2019-05-06 True
# SWMKOB-A error Unable to read URL: https://finance.yahoo.com/quote/SWMKOB-A/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fSWMKOB-A%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fSWMKOB-A%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# SWL.AX new date:: 2017-07-06 2019-05-06 True
# SWL.AX error Unable to read URL: https://finance.yahoo.com/quote/SWL.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fSWL.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fSWL.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# SWE.AX new date:: 2017-07-06 2019-05-06 True
# SWE.AX error Unable to read URL: https://finance.yahoo.com/quote/SWE.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fSWE.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fSWE.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# TLM.AX new date:: 2017-07-06 2019-05-06 True
# TLM.AX error Unable to read URL: https://finance.yahoo.com/quote/TLM.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTLM.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTLM.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# TAU.AX new date:: 2017-07-06 2019-05-06 True
# TAU.AX error Unable to read URL: https://finance.yahoo.com/quote/TAU.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTAU.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTAU.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# TMM.AX new date:: 2017-07-06 2019-05-06 True
# TMM.AX error Unable to read URL: https://finance.yahoo.com/quote/TMM.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTMM.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTMM.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# TAN.AX new date:: 2017-07-06 2019-05-06 True
# TAN.AX error Unable to read URL: https://finance.yahoo.com/quote/TAN.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTAN.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTAN.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# TAG.AX new date:: 2017-07-06 2019-05-06 True
# TAG.AX error Unable to read URL: https://finance.yahoo.com/quote/TAG.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTAG.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTAG.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# TBR.AX new date:: 2017-07-06 2019-05-06 True
# TBR.AX error Unable to read URL: https://finance.yahoo.com/quote/TBR.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTBR.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTBR.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# TCO.AX new date:: 2017-07-06 2019-05-06 True
# TCO.AX error Unable to read URL: https://finance.yahoo.com/quote/TCO.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTCO.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTCO.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# TCLN.AX new date:: 2017-07-06 2019-05-06 True
# TCLN.AX error Unable to read URL: https://finance.yahoo.com/quote/TCLN.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTCLN.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTCLN.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# TGP.AX new date:: 2017-07-06 2019-05-06 True
# TGP.AX error Unable to read URL: https://finance.yahoo.com/quote/TGP.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTGP.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTGP.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# TGA.AX new date:: 2017-07-06 2019-05-06 True
# TGA.AX error Unable to read URL: https://finance.yahoo.com/quote/TGA.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTGA.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTGA.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# TIS.AX new date:: 2017-07-06 2019-05-06 True
# TIS.AX error Unable to read URL: https://finance.yahoo.com/quote/TIS.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTIS.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTIS.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# THO.AX new date:: 2017-07-06 2019-05-06 True
# THO.AX error Unable to read URL: https://finance.yahoo.com/quote/THO.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTHO.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTHO.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# TNK.AX new date:: 2017-07-06 2019-05-06 True
# TNK.AX error Unable to read URL: https://finance.yahoo.com/quote/TNK.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTNK.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTNK.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# TIK.AX new date:: 2017-07-06 2019-05-06 True
# TIK.AX error Unable to read URL: https://finance.yahoo.com/quote/TIK.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTIK.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTIK.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# TKL.AX new date:: 2017-07-06 2019-05-06 True
# TKL.AX error Unable to read URL: https://finance.yahoo.com/quote/TKL.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTKL.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTKL.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# TLSKOG-A new date:: 2017-07-06 2019-05-06 True
# TLSKOG-A error Unable to read URL: https://finance.yahoo.com/quote/TLSKOG-A/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTLSKOG-A%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fTLSKOG-A%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# TLSKOQ-A new date:: 2017-07-06 2019-05-06 True
