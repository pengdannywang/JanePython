# %%
# -*- coding: utf-8 -*-

import pandas as pd
from sarimaxModel import forcastStocks
from loadstocks import loadStocksByTickers
from loadstocks import loadAuTickersFromYahooExcel
# We will look at stock prices over the past year, starting at January 1, 2016

path='/root/pythondev/JanePython/'
inputfile = path+'Yahoo.xlsx'
outputfile = path+'stocks9.csv'

tickers=loadAuTickersFromYahooExcel(inputfile)
tickers=tickers[1800:2000]
stocks=loadStocksByTickers(tickers,outputfile)
print(len(stocks))
# Out:
# JCI.AX new date:: 2017-07-06 2019-05-06 True
# JCS.AX new date:: 2017-07-06 2019-05-06 True
# JPR.AX new date:: 2017-07-06 2019-05-06 True
# JPR.AX error cannot reindex from a duplicate axis
# KPO.AX new date:: 2017-07-06 2019-05-06 True
# KRC.AX new date:: 2017-07-06 2019-05-06 True
# KRC.AX error No data fetched for symbol KRC.AX using YahooDailyReader
# KNO.AX new date:: 2017-07-06 2019-05-06 True
# KPR.AX new date:: 2017-07-06 2019-05-06 True
# KPR.AX error No data fetched for symbol KPR.AX using YahooDailyReader
# KRB.AX new date:: 2017-07-06 2019-05-06 True
# KRB.AX error No data fetched for symbol KRB.AX using YahooDailyReader
# KTA.AX new date:: 2017-07-06 2019-05-06 True
# D13.AX new date:: 2017-07-06 2019-05-06 True
# D13.AX error No data fetched for symbol D13.AX using YahooDailyReader
# LRS.AX new date:: 2017-07-06 2019-05-06 True
# RLC.AX new date:: 2017-07-06 2019-05-06 True
# LAA.AX new date:: 2017-07-06 2019-05-06 True
# LAM.AX new date:: 2017-07-06 2019-05-06 True
# LAM.AX error No data fetched for symbol LAM.AX using YahooDailyReader
# SLR.AX new date:: 2017-07-06 2019-05-06 True
# SO4.AX new date:: 2017-07-06 2019-05-06 True
# LSA.AX new date:: 2017-07-06 2019-05-06 True
# LTN.AX new date:: 2017-07-06 2019-05-06 True
# LTN.AX error No data fetched for symbol LTN.AX using YahooDailyReader
# LLCCD.AX new date:: 2017-07-06 2019-05-06 True
# LLCCD.AX error No data fetched for symbol LLCCD.AX using YahooDailyReader
# LRR.AX new date:: 2017-07-06 2019-05-06 True
# LRR.AX error No data fetched for symbol LRR.AX using YahooDailyReader
# 3PL.AX new date:: 2017-07-06 2019-05-06 True
# LMR.AX new date:: 2017-07-06 2019-05-06 True
# LMR.AX error No data fetched for symbol LMR.AX using YahooDailyReader
# LRL.AX new date:: 2017-07-06 2019-05-06 True
# LRL.AX error No data fetched for symbol LRL.AX using YahooDailyReader
# LGD.AX new date:: 2017-07-06 2019-05-06 True
# LGD.AX error cannot reindex from a duplicate axis
# LOV.AX new date:: 2017-07-06 2019-05-06 True
# LPE.AX new date:: 2017-07-06 2019-05-06 True
# LPE.AX error cannot reindex from a duplicate axis
# LSR.AX new date:: 2017-07-06 2019-05-06 True
# LWP.AX new date:: 2017-07-06 2019-05-06 True
# LWP.AX error No data fetched for symbol LWP.AX using YahooDailyReader
# MZN.AX new date:: 2017-07-06 2019-05-06 True
# MQGCD.AX new date:: 2017-07-06 2019-05-06 True
# MQGCD.AX error No data fetched for symbol MQGCD.AX using YahooDailyReader
# MGY.AX new date:: 2017-07-06 2019-05-06 True
# MGY.AX error No data fetched for symbol MGY.AX using YahooDailyReader
# MGT.AX new date:: 2017-07-06 2019-05-06 True
# MYE.AX new date:: 2017-07-06 2019-05-06 True
# MBN.AX new date:: 2017-07-06 2019-05-06 True
# MBN.AX error No data fetched for symbol MBN.AX using YahooDailyReader
# MBT.AX new date:: 2017-07-06 2019-05-06 True
# MBT.AX error No data fetched for symbol MBT.AX using YahooDailyReader
# MBC.AX new date:: 2017-07-06 2019-05-06 True
# MBC.AX error 'Date'
# MCS.AX new date:: 2017-07-06 2019-05-06 True
# MCS.AX error 'Date'
# MCH.AX new date:: 2017-07-06 2019-05-06 True
# MCH.AX error No data fetched for symbol MCH.AX using YahooDailyReader
# MCT.AX new date:: 2017-07-06 2019-05-06 True
# MMS.AX new date:: 2017-07-06 2019-05-06 True
# MSG.AX new date:: 2017-07-06 2019-05-06 True
# MDR.AX new date:: 2017-07-06 2019-05-06 True
# MPLKOQ-A new date:: 2017-07-06 2019-05-06 True
# MPLKOQ-A error No data fetched for symbol MPLKOQ-A using YahooDailyReader
# MUI.AX new date:: 2017-07-06 2019-05-06 True
# MUI.AX error No data fetched for symbol MUI.AX using YahooDailyReader
# MNE.AX new date:: 2017-07-06 2019-05-06 True
# MNE.AX error No data fetched for symbol MNE.AX using YahooDailyReader
# MLA.AX new date:: 2017-07-06 2019-05-06 True
# MLA.AX error Unable to read URL: https://finance.yahoo.com/quote/MLA.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMLA.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMLA.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# MRQ.AX new date:: 2017-07-06 2019-05-06 True
# MRQ.AX error Unable to read URL: https://finance.yahoo.com/quote/MRQ.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMRQ.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMRQ.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# SXT.AX new date:: 2017-07-06 2019-05-06 True
# SXT.AX error Unable to read URL: https://finance.yahoo.com/quote/SXT.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fSXT.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fSXT.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# ENT.AX new date:: 2017-07-06 2019-05-06 True
# ENT.AX error Unable to read URL: https://finance.yahoo.com/quote/ENT.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fENT.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fENT.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# MTD.AX new date:: 2017-07-06 2019-05-06 True
# MTD.AX error Unable to read URL: https://finance.yahoo.com/quote/MTD.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMTD.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMTD.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# MKB.AX new date:: 2017-07-06 2019-05-06 True
# MKB.AX error Unable to read URL: https://finance.yahoo.com/quote/MKB.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMKB.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMKB.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# OSP.AX new date:: 2017-07-06 2019-05-06 True
# OSP.AX error Unable to read URL: https://finance.yahoo.com/quote/OSP.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fOSP.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fOSP.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# MGB.AX new date:: 2017-07-06 2019-05-06 True
# MGB.AX error Unable to read URL: https://finance.yahoo.com/quote/MGB.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMGB.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMGB.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# MGL.AX new date:: 2017-07-06 2019-05-06 True
# MGL.AX error Unable to read URL: https://finance.yahoo.com/quote/MGL.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMGL.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMGL.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# MGZ.AX new date:: 2017-07-06 2019-05-06 True
# MGZ.AX error Unable to read URL: https://finance.yahoo.com/quote/MGZ.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMGZ.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMGZ.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# MGV.AX new date:: 2017-07-06 2019-05-06 True
# MGV.AX error Unable to read URL: https://finance.yahoo.com/quote/MGV.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMGV.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMGV.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# MGS.AX new date:: 2017-07-06 2019-05-06 True
# MGS.AX error Unable to read URL: https://finance.yahoo.com/quote/MGS.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMGS.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMGS.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# MGC.AX new date:: 2017-07-06 2019-05-06 True
# MGC.AX error Unable to read URL: https://finance.yahoo.com/quote/MGC.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMGC.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMGC.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# MHC.AX new date:: 2017-07-06 2019-05-06 True
# MHC.AX error Unable to read URL: https://finance.yahoo.com/quote/MHC.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMHC.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMHC.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# A2M.AX new date:: 2017-07-06 2019-05-06 True
# A2M.AX error Unable to read URL: https://finance.yahoo.com/quote/A2M.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fA2M.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fA2M.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# MYT.AX new date:: 2017-07-06 2019-05-06 True
# MYT.AX error Unable to read URL: https://finance.yahoo.com/quote/MYT.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMYT.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMYT.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# VAR.AX new date:: 2017-07-06 2019-05-06 True
# VAR.AX error Unable to read URL: https://finance.yahoo.com/quote/VAR.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fVAR.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fVAR.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# MRD.AX new date:: 2017-07-06 2019-05-06 True
# MRD.AX error Unable to read URL: https://finance.yahoo.com/quote/MRD.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMRD.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fMRD.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# PDZ.AX new date:: 2017-07-06 2019-05-06 True
# PDZ.AX error Unable to read URL: https://finance.yahoo.com/quote/PDZ.AX/history?period1=1499277600&period2=1557165599&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fPDZ.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2ffinance.yahoo.com%2fquote%2fPDZ.AX%2fhistory%3fperiod1%3d1499277600%26period2%3d1557165599%26interval%3d1d%26frequency%3d1d%26filter%3dhistory\'"></noscript>\n</html>\n'
# SWK.AX new date:: 2017-07-06 2019-05-06 True
