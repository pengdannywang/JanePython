# %%
# -*- coding: utf-8 -*-

import pandas as pd
from sarimaxModel import forcastStocks
from loadstocks import loadStocksByTickers
from loadstocks import loadAuNotNaTickersFromYahooExcel
# We will look at stock prices over the past year, starting at January 1, 2016

path='/root/pythondev/JanePython/'
inputfile = path+'Yahoo.xlsx'
outputfile = 'stocks1.csv'
savepath=path+outputfile
ds=pd.read_csv(savepath,parse_dates=['Date'],index_col='Date')
len(ds.columns)
ds[ds.columns[ds.isna().any()]]
# Out:
#             SBB.AX  BRK.AX    MPX.AX  ICG.AX  CLA.AX    ORG.AX     ANZ.AX  \
# Date
# 2017-07-07   0.011     NaN       NaN     NaN     NaN       NaN        NaN
# 2017-07-10   0.011   0.010  0.272708  0.0090  0.0310  6.806250  26.385042
# 2017-07-11   0.011   0.010  0.272708  0.0090  0.0300  6.825978  26.486029
# 2017-07-12   0.011   0.010  0.272708  0.0090  0.0300  6.885163  26.082083
# 2017-07-13   0.011   0.010  0.272708  0.0090  0.0290  6.895027  26.238152
# 2017-07-14   0.011   0.010  0.272708  0.0090  0.0310  7.092310  26.495211
# 2017-07-17   0.011   0.010  0.272708  0.0080  0.0300  7.131766  26.394220
# 2017-07-18   0.011   0.010  0.272708  0.0080  0.0290  7.141630  25.981094
# 2017-07-19   0.011   0.010  0.272708  0.0090  0.0280  7.092310  27.000141
# 2017-07-20   0.011   0.011  0.272708  0.0090  0.0300  7.112038  27.771313
# 2017-07-21   0.011   0.011  0.272708  0.0080  0.0290  7.052854  27.642784
# 2017-07-24   0.011   0.010  0.272708  0.0080  0.0300  6.776658  27.440809
# 2017-07-25   0.011   0.010  0.272708  0.0090  0.0320  6.648424  27.550978
# 2017-07-26   0.011   0.010  0.272708  0.0080  0.0340  6.825978  27.798855
# 2017-07-27   0.013   0.010  0.272708  0.0080  0.0360  6.825978  27.817213
# 2017-07-28   0.013   0.010  0.272708  0.0080  0.0360  6.766794  27.266378
# 2017-07-31   0.013   0.010  0.272708  0.0080  0.0360  6.825978  27.202114
# 2017-08-01   0.013   0.010  0.272708  0.0090  0.0370  7.092310  27.321465
# 2017-08-02   0.013   0.010  0.272708  0.0080  0.0400  7.042989  27.211294
# 2017-08-03   0.013   0.010  0.272708  0.0080  0.0400  7.082446  27.156212
# 2017-08-04   0.011   0.010  0.272708  0.0080  0.0420  7.102174  27.073586
# 2017-08-07   0.012   0.010  0.272708  0.0080  0.0430  7.190951  27.358185
# 2017-08-08   0.011   0.010  0.272708  0.0080  0.0410  7.200816  27.257198
# 2017-08-09   0.011   0.010  0.272708  0.0080  0.0420  7.052854  27.459171
# 2017-08-10   0.011   0.009  0.272708  0.0070  0.0420  6.934484  27.385727
# 2017-08-11   0.011   0.009  0.272708  0.0070  0.0420  6.786522  26.862432
# 2017-08-14   0.011   0.010  0.272708  0.0070  0.0420  6.855571  27.018503
# 2017-08-15   0.011   0.010  0.272708  0.0080  0.0410  6.756929  27.367363
# 2017-08-16   0.011   0.012  0.272708  0.0080  0.0420  7.121902  27.927382
# 2017-08-17   0.011   0.012  0.272708  0.0090  0.0470  7.240272  27.872297
# ...            ...     ...       ...     ...     ...       ...        ...
# 2019-03-21   0.012   0.014  0.300000  0.0040  0.0190  7.560000  26.520000
# 2019-03-24   0.012   0.013  0.300000  0.0040  0.0190  7.220000  25.920000
# 2019-03-25   0.012   0.012  0.300000  0.0040  0.0180  7.130000  25.840000
# 2019-03-26   0.012   0.013  0.300000  0.0040  0.0175  7.080000  25.940001
# 2019-03-27   0.012   0.012  0.300000  0.0040  0.0160  7.230000  26.020000
# 2019-03-28   0.012   0.012  0.300000  0.0040  0.0160  7.200000  26.030001
# 2019-03-31   0.012   0.012  0.300000  0.0050  0.0160  7.150000  26.270000
# 2019-04-01   0.012   0.012  0.300000  0.0040  0.0180  7.140000  26.469999
# 2019-04-02   0.012   0.014  0.300000  0.0040  0.0190  7.180000  26.440001
# 2019-04-03   0.012   0.014  0.300000  0.0035  0.0170  7.110000  26.260000
# 2019-04-04   0.012   0.014  0.300000  0.0040  0.0180  7.100000  25.950001
# 2019-04-08   0.012   0.015  0.300000  0.0040  0.0170  7.250000  25.799999
# 2019-04-09   0.012   0.015  0.300000  0.0040  0.0190  7.310000  25.650000
# 2019-04-10   0.012   0.015  0.300000  0.0040  0.0190  7.230000  25.680000
# 2019-04-11   0.012   0.015  0.300000  0.0040  0.0180  7.200000  25.510000
# 2019-04-12   0.012   0.015  0.300000  0.0040  0.0180  7.250000  26.020000
# 2019-04-15   0.012   0.014  0.300000  0.0040  0.0180  7.290000  26.250000
# 2019-04-16   0.012   0.014  0.300000  0.0035  0.0180  7.290000  26.410000
# 2019-04-17   0.012   0.014  0.300000  0.0035  0.0170  7.300000  26.719999
# 2019-04-18   0.012   0.014  0.300000  0.0040  0.0170  7.320000  26.780001
# 2019-04-23   0.012   0.014  0.300000  0.0035  0.0160  7.570000  27.080000
# 2019-04-24   0.012   0.014  0.300000  0.0040  0.0160  7.570000  27.350000
# 2019-04-26   0.012   0.013  0.300000  0.0040  0.0160  7.480000  27.400000
# 2019-04-29   0.012   0.014  0.300000  0.0040  0.0160  7.450000  27.330000
# 2019-04-30   0.012   0.014  0.300000  0.0040  0.0170  7.370000  27.200001
# 2019-05-01   0.012   0.013  0.300000  0.0040  0.0170  7.660000  27.950001
# 2019-05-02   0.012   0.013  0.300000  0.0045  0.0180  7.660000  27.270000
# 2019-05-03   0.012   0.013  0.300000  0.0040  0.0170  7.520000  27.410000
# 2019-05-06   0.012   0.012  0.300000  0.0040  0.0170  7.410000  27.549999
# 2019-05-07     NaN   0.012  0.300000  0.0040  0.0180  7.520000  27.500000
#
#               XRF.AX     WOW.AX    WAT.AX   ...    HLX.AX  IEC.AX  IPB.AX  \
# Date                                        ...
# 2017-07-07       NaN        NaN       NaN   ...       NaN     NaN     NaN
# 2017-07-10  0.169682  24.059116  1.620025   ...     0.033   0.012   0.015
# 2017-07-11  0.169682  24.040445  1.620025   ...     0.033   0.012   0.015
# 2017-07-12  0.169682  23.975092  1.620025   ...     0.033   0.012   0.015
# 2017-07-13  0.155137  24.273849  1.620025   ...     0.040   0.012   0.015
# Out:
# DatetimeIndex(['2017-07-07', '2017-07-10', '2017-07-11', '2017-07-12',
#                '2017-07-13', '2017-07-14', '2017-07-17', '2017-07-18',
#                '2017-07-19', '2017-07-20',
#                ...
#                '2019-04-23', '2019-04-24', '2019-04-26', '2019-04-29',
#                '2019-04-30', '2019-05-01', '2019-05-02', '2019-05-03',
#                '2019-05-06', '2019-05-07'],
#               dtype='datetime64[ns]', name='Date', length=463, freq=None)

# %%
import numpy as np
np.unique(ds.columns)
# Out:
# array(['1AL.AX', '3PL.AX', '4DS.AX', ..., 'ZIM.AX', 'ZIP.AX', 'ZNC.AX'],
#       dtype=object)

# %%
import pandas as pd
import pandas_datareader.data as web   # Package and modules for importing data; this code may change depending on pandas version
import datetime
import numpy as np
import os
import random
from datetime import timedelta
import statsmodels.api as sm
# SARIMAX example
from statsmodels.tsa.statespace.sarimax import SARIMAX
import sys, getopt
path='/root/pythondev/JanePython/'
inputfile = path+'Yahoo.xlsx'
stock_names=pd.read_excel(inputfile,header=3,usecols=4)

au_stocks=stock_names[stock_names['Country']=='USA']
au_tickers=au_stocks[au_stocks['Category Name'].notna()]['Ticker']
tickers =au_tickers.tolist()
tickers
# Out:
# ['AAPL',
#  'BAC',
#  'AMZN',
#  'T',
#  'GOOG',
#  'MO',
#  'DAL',
#  'AA',
#  'AXP',
#  'DD',
#  'BABA',
#  'ABT',
#  'UA',
#  'AMAT',
#  'AMGN',
#  'AAL',
#  'AIG',
#  'ALL',
#  'ADBE',
#  'GOOGL',
#  'ACN',
#  'ABBV',
#  'MT',
#  'LLY',
#  'AGN',
#  'APA',
#  'ADP',
#  'APC',
#  'AKAM',
#  'NLY',
#  'ABX',
#  'ATVI',
#  'ADSK',
#  'ADM',
#  'WBA',
#  'ARNA',
#  'LUV',
#  'ACAD',
#  'PANW',
#  'AMD',
#  'AET',
#  'AEP',
#  'ALXN',
#  'AVGO',
#  'EA',
#  'DB',
#  'AEM',
#  'APD',
#  'AMBA',
#  'NVS',
#  'ANF',
#  'LULU',
#  'RAD',
#  'ARRY',
#  'AGNC',
#  'JBLU',
#  'A',
#  'ORLY',
#  'FOLD',
#  'AZO',
#  'AN',
#  'AZN',
#  'AES',
#  'BUD',
#  'ARR',
#  'BDX',
#  'AKS',
#  'AB',
#  'ACOR',
#  'CS',
#  'AFL',
#  'ADI',
#  'ACIW',
#  'AMP',
#  'AVP',
#  'AMTD',
#  'AEO',
#  'AWK',
#  'NVO',
#  'ALK',
#  'PAA',
#  'AAP',
#  'NAT',
#  'FNMA',
#  'AIV',
#  'AGIO',
#  'AEE',
#  'UBS',
#  'AVXL',
#  'ARLP',
#  'ANTM',
#  'AGU',
#  'AG',
#  'AFSI',
#  'ABC',
#  'STO',
#  'ATI',
#  'AVB',
#  'ATW',
#  'ALNY',
#  'LH',
#  'AVY',
#  'AUY',
#  'ASH',
#  'ACXM',
#  'ACHN',
#  'ACET',
#  'ABMD',
#  'ABM',
#  'LIFE',
#  'ATO',
#  'AON',
#  'ADXS',
#  'ADC',
#  'APU',
#  'SAVE',
#  'AKRX',
#  'ADS',
#  'ABAX',
#  'AYI',
#  'AMT',
#  'ALDR',
#  'ACM',
#  'ATRS',
#  'ARW',
#  'ARI',
#  'AR',
#  'AMC',
#  'AL',
#  'AGEN',
#  'AAN',
#  'WTR',
#  'BAH',
#  'AXAS',
#  'AVT',
#  'ALB',
#  'AIZ',
#  'SAIC',
#  'CAR',
#  'AU',
#  'APH',
#  'ANTH',
#  'AMX',
#  'AMDA',
#  'AI',
#  'ABCO',
#  'WMC',
#  'JKHY',
#  'AVAV',
#  'AMKR',
#  'ACH',
#  'AEIS',
#  'Y',
#  'MTGE',
#  'CENX',
#  'ASPS',
#  'AMRN',
#  'AMPE',
#  'AMAG',
#  'ALKS',
#  'ADES',
#  'AAON',
#  'XLRN',
#  'VRSK',
#  'VJET',
#  'OA',
#  'ATLS',
#  'APTS',
#  'APO',
#  'ALSK',
#  'ALG',
#  'AHC',
#  'ACTG',
#  'RBA',
#  'MAA',
#  'BAM',
#  'ATHN',
#  'AT',
#  'ASX',
#  'ARCO',
#  'ANET',
#  'ANCX',
#  'AIR',
#  'AF',
#  'WAB',
#  'RS',
#  'PKG',
#  'AXDX',
#  'AVHI',
#  'AVA',
#  'ATHX',
#  'ARWR',
#  'ANGI',
#  'AMG',
#  'ALSN',
#  'ALGN',
#  'AKBA',
#  'AGO',
#  'AEZS',
#  'ACRX',
#  'ROK',
#  'GLPI',
#  'AZZ',
#  'ATRC',
#  'ARRS',
#  'ARMK',
#  'AOS',
#  'ANFI',
#  'AMID',
#  'AMCX',
#  'ALIM',
#  'ALE',
#  'AHT',
#  'ABB',
#  'SPR',
#  'SEE',
#  'DLPH',
#  'CBL',
#  'BBVA',
#  'AYR',
#  'APOG',
#  'ANDE',
#  'AMSC',
#  'AMRS',
#  'AMED',
#  'ALEX',
#  'ALCO',
#  'ADUS',
#  'ACTA',
#  'ACST',
#  'AAWW',
#  'WMS',
#  'PAG',
#  'MDRX',
#  'KLIC',
#  'ETH',
#  'AZPN',
#  'AXE',
#  'APRI',
#  'AMH',
#  'AME',
#  'AJG',
#  'AHGP',
#  'AGCO',
#  'AERI',
#  'ACRE',
#  'WAL',
#  'SYT',
#  'SHLM',
#  'NOG',
#  'HTA',
#  'GIII',
#  'DAVE',
#  'CVU',
#  'ATU',
#  'ASTI',
#  'AREX',
#  'ARE',
#  'ANSS',
#  'AMNB',
#  'AMBS',
#  'ALR',
#  'AIN',
#  'AHL',
#  'AGX',
#  'ADTN',
#  'ADMS',
#  'ACLS',
#  'ABG',
#  'ZX',
#  'KS',
#  'HOLI',
#  'GPI',
#  'AXTA',
#  'AWR',
#  'AWI',
#  'AVEO',
#  'AUO',
#  'ATHM',
#  'ATAX',
#  'ASM',
#  'ANH',
#  'ALX',
#  'AGI',
#  'AER',
#  'AE',
#  'PETX',
#  'ODC',
#  'NAO',
#  'KAR',
#  'HUSA',
#  'HIVE',
#  'FMS',
#  'DOX',
#  'CXW',
#  'AXS',
#  'AXL',
#  'AWX',
#  'AVID',
#  'ASNA',
#  'ASGN',
#  'ARDX',
#  'ARAY',
#  'AQXP',
#  'APT',
#  'APDN',
#  'AMBC',
#  'ALGT',
#  'ALDW',
#  'AIT',
#  'AIMC',
#  'AEL',
#  'AEHR',
#  'ADHD',
#  'ACUR',
#  'ACHC',
#  'ACFC',
#  'ACCO',
#  'ABY',
#  'TA',
#  'RPAI',
#  'MANH',
#  'LAMR',
#  'AXN',
#  'ATRO',
#  'ATNI',
#  'ARCW',
#  'APEI',
#  'AP',
#  'ANIK',
#  'ANGO',
#  'AMOT',
#  'AM',
#  'ALV',
#  'ALOG',
#  'AKR',
#  'AEGN',
#  'WRLD',
#  'UHAL',
#  'UAMY',
#  'SAH',
#  'NAII',
#  'CACC',
#  'ATSG',
#  'ASB',
#  'ARTX',
#  'AROW',
#  'ARCB',
#  'AMRK',
#  'ALRM',
#  'AHP',
#  'AGRX',
#  'AFAM',
#  'ADK',
#  'ABTL',
#  'ABCD',
#  'AAOI',
#  'USAP',
#  'STFC',
#  'STAY',
#  'SEED',
#  'RGA',
#  'IDSA',
#  'CEA',
#  'BREW',
#  'AXR',
#  'AVD',
#  'AUDC',
#  'ATRI',
#  'ATOS',
#  'ARC',
#  'AOSL',
#  'AOI',
#  'AMWD',
#  'ALLY',
#  'AIRI',
#  'ACGL',
#  'ACFN',
#  'ABR',
#  'ABCB',
#  'RAIL',
#  'MITT',
#  'HASI',
#  'GOL',
#  'GIL',
#  'ATTO',
#  'ATR',
#  'ATNM',
#  'ASTC',
#  'ASR',
#  'ASC',
#  'ARTNA',
#  'ADRO',
#  'ACNB',
#  'AAV',
#  'AAT',
#  'ZNH',
#  'LNT',
#  'KALU',
#  'HOMB',
#  'FAF',
#  'FAC',
#  'CAAS',
#  'BETR',
#  'ATV',
#  'ATLC',
#  'AST',
#  'ARIS',
#  'ARCI',
#  'ANY',
#  'ANIP',
#  'AMSWA',
#  'AMSF',
#  'ALLT',
#  'AKTX',
#  'AGYS',
#  'AFG',
#  'WAIR',
#  'RESI',
#  'LND',
#  'DGLY',
#  'CADC',
#  'AWRE',
#  'AVNW',
#  'ATRM',
#  'APPF',
#  'AMRI',
#  'AMCN',
#  'AMCF',
#  'ALLE',
#  'AJRD',
#  'AHH',
#  'AGM',
#  'AGII',
#  'AFCB',
#  'ADMA',
#  'AAME',
#  'TEO',
#  'SINO',
#  'NOA',
#  'JAGX',
#  'DIT',
#  'CRMT',
#  'CGA',
#  'ATEN',
#  'ARII',
#  'ARDM',
#  'ARCX',
#  'APPS',
#  'APHB',
#  'ANW',
#  'ANAT',
#  'AKAO',
#  'AETI',
#  'ADMP',
#  'ACC',
#  'REX',
#  'PAC',
#  'NNA',
#  'NAUH',
#  'HMNY',
#  'GABC',
#  'CACQ',
#  'BTI',
#  'AXPW',
#  'AVX',
#  'ASUR',
#  'ASMB',
#  'ASFI',
#  'ASCMA',
#  'ASCC',
#  'ARES',
#  'AQMS',
#  'ANCB',
#  'AMRC',
#  'AKG',
#  'ACY',
#  'ABIO',
#  'AAC',
#  'VLRS',
#  'TEAM',
#  'SORL',
#  'NEN',
#  'FWP',
#  'EVTC',
#  'AXU',
#  'ATAI',
#  'ARQL',
#  'ARKR',
#  'AMRB',
#  'AMBR',
#  'ALQA',
#  'ALOT',
#  'AHPI',
#  'AGRO',
#  'ADX',
#  'ADAT',
#  'ADAP',
#  'ACU',
#  'TKC',
#  'PRTS',
#  'POPE',
#  'PEO',
#  'NADL',
#  'GAM',
#  'EAGL',
#  'DLA',
#  'BRKS',
#  'AUBN',
#  'ASYS',
#  'ASA',
#  'AMPH',
#  'ALDX',
#  'AEY',
#  'ABUS',
#  'AAPC',
#  'SHOS',
#  'RYAM',
#  'PAHC',
#  'FWRD',
#  'CALI',
#  'AXON',
#  'AXGN',
#  'AUMN',
#  'ASRV',
#  'ASBB',
#  'ARTW',
#  'APWC',
#  'APAM',
#  'AMS',
#  'AMFC',
#  'ALN',
#  'AGFS',
#  'AEMD',
#  'AAMC',
#  'UNAM',
#  'HVCW',
#  'MPAA',
#  'JAX',
#  'EARS',
#  'AXTI',
#  'ATTU',
#  'ATLO',
#  'ASTE',
#  'ASND',
#  'ARL',
#  'AMTX',
#  'AFMD',
#  'AFFY',
#  'RKDA',
#  'IPCC',
#  'FTAI',
#  'ALAN',
#  'AKO-A',
#  'AJX',
#  'AFH',
#  'AEGG',
#  'PHX',
#  'DYSL',
#  'BRSS',
#  'BLVD',
#  'ASKH',
#  'ALTX',
#  'AIMT',
#  'AERG',
#  'ACLZ',
#  'SKAS',
#  'PZE',
#  'NORD',
#  'MOG-A',
#  'BHAC',
#  'ANSU',
#  'ALYI',
#  'ALLM',
#  'AIRT',
#  'ASPN',
#  'ARBV',
#  'AOXY',
#  'AOGN',
#  'ALOD',
#  'AKO-B',
#  'ABHD',
#  'ABCP',
#  'AAU',
#  'IAIC',
#  'HNNA',
#  'GTN-A',
#  'FMAO',
#  'DLYT',
#  'AVOI',
#  'AVGR',
#  'AUXO',
#  'AUNB',
#  'ATOC',
#  'ATEA',
#  'ASCCF',
#  'ARTH',
#  'ARGB',
#  'ANDA',
#  'AMPG',
#  'AMEH',
#  'AMBOY',
#  'AEYE',
#  'AERO',
#  'ADVC',
#  'ABBB',
#  'WTER',
#  'TWCF',
#  'TGRO',
#  'CBAI',
#  'SIGL',
#  'ALME',
#  'HCAC',
#  'HADV',
#  'FUTU',
#  'FBAK',
#  'FABK',
#  'DBRM',
#  'AUSI',
#  'ATAR',
#  'ANAV',
#  'AMIN',
#  'AMBZ',
#  'ALSE',
#  'ALRT',
#  'AKTS',
#  'AHII',
#  'AHFP',
#  'AGIN',
#  'AFBG',
#  'ADLS',
#  'ABNK',
#  'ABKI',
#  'VOIL',
#  'UBAB',
#  'ARCS',
#  'PTPF',
#  'PRKA',
#  'HISP',
#  'GLUX',
#  'SOUL',
#  'USAE',
#  'AXRX',
#  'AXIM',
#  'AVBH',
#  'AUTCF',
#  'ASCK',
#  'ARNI',
#  'APVS',
#  'AMTY',
#  'AMSE',
#  'AMRR',
#  'AMCO',
#  'AMBK',
#  'AMAR',
#  'AKVA',
#  'ADGL',
#  'ABCE',
#  'AASP',
#  'ARYX',
#  'BTFL',
#  'PSSR',
#  'PGRD',
#  'AWGI',
#  'HUTN',
#  'GAHC',
#  'EXAD',
#  'CRYO',
#  'LOGL',
#  'CHCR',
#  'AZRH',
#  'DCAC',
#  'ASPW',
#  'ASPU',
#  'ANDR',
#  'AMNL',
#  'AMLM',
#  'ALFE',
#  'AIRW',
#  'AFBA',
#  'ACUS',
#  'ACRB',
#  'ACAR',
#  'ABTO',
#  'AAST',
#  'BA',
#  'IBM',
#  'BP',
#  'BAX',
#  'BIDU',
#  'BRK-A',
#  'BBY',
#  'BX',
#  'BSX',
#  'BIIB',
#  'BMY',
#  'BBBY',
#  'USB',
#  'BLK',
#  'YUM',
#  'BTU',
#  'MNST',
#  'BK',
#  'FITB',
#  'ZBH',
#  'BHP',
#  'CZBS',
#  'GBSN',
#  'BEN',
#  'GNCA',
#  'LB',
#  'BDSI',
#  'BMO',
#  'BBT',
#  'BPT',
#  'GALE',
#  'BKS',
#  'HRB',
#  'BWLD',
#  'STI',
#  'TAP',
#  'CNBKA',
#  'CBRL',
#  'BITA',
#  'BCS',
#  'TD',
#  'MTB',
#  'BXP',
#  'BTX',
#  'BMRN',
#  'RY',
#  'BCR',
#  'HBAN',
#  'BCE',
#  'SWK',
#  'PDLI',
#  'BRCD',
#  'B',
#  'BGCP',
#  'BWA',
#  'BLL',
#  'TOL',
#  'SAM',
#  'HEB',
#  'BOX',
#  'BC',
#  'PBI',
#  'KERX',
#  'CBB',
#  'BKE',
#  'BGS',
#  'BCEI',
#  'BBG',
#  'PACB',
#  'CM',
#  'BBL',
#  'TUP',
#  'SB',
#  'BKMU',
#  'BG',
#  'GABA',
#  'DNKN',
#  'BRS',
#  'BPOP',
#  'BLCM',
#  'BGC',
#  'PBYI',
#  'NCS',
#  'BLDP',
#  'BBD',
#  'SAN',
#  'EBS',
#  'BPL',
#  'BOBE',
#  'BLUE',
#  'BDL',
#  'STL',
#  'ICON',
#  'FIBK',
#  'EWBC',
#  'EAT',
#  'CFR',
#  'BNS',
#  'BMS',
#  'BCRX',
#  'BCPC',
#  'BAS',
#  'WBK',
#  'SYN',
#  'SBGI',
#  'NWBO',
#  'BRKR',
#  'BOKF',
#  'BKD',
#  'BIO',
#  'WRB',
#  'VLY',
#  'VIVO',
#  'PVCT',
#  'ONB',
#  'COKE',
#  'CBI',
#  'BJRI',
#  'BCOR',
#  'UBSH',
#  'TCBI',
#  'SGMO',
#  'RRGB',
#  'ROX',
#  'LCUT',
#  'IBTX',
#  'IBN',
#  'FFBC',
#  'DNB',
#  'BZUN',
#  'BIP',
#  'BHE',
#  'BGFV',
#  'SONA',
#  'SASR',
#  'NXST',
#  'EVBN',
#  'CBK',
#  'BYD',
#  'BVSN',
#  'BR',
#  'BMI',
#  'BIG',
#  'BDC',
#  'BCO',
#  'BAP',
#  'BAK',
#  'ZION',
#  'VRA',
#  'SFBS',
#  'SBNY',
#  'RATE',
#  'PBH',
#  'JBSS',
#  'JACK',
#  'CTIC',
#  'BZH',
#  'BV',
#  'BSBR',
#  'BRC',
#  'BEBE',
#  'BBOX',
#  'BAA',
#  'TECH',
#  'SPB',
#  'NRIM',
#  'NAVB',
#  'LYG',
#  'IBKR',
#  'BTE',
#  'BPI',
#  'OLBK',
#  'NYCB',
#  'NBIX',
#  'NBHC',
#  'FMBI',
#  'FIVE',
#  'CNOB',
#  'CALA',
#  'BXS',
#  'BPTH',
#  'BOH',
#  'BKU',
#  'BKH',
#  'BH',
#  'BFAM',
#  'BDN',
#  'SBLK',
#  'SBCF',
#  'ROLL',
#  'PSB',
#  'PBIP',
#  'PB',
#  'HTBX',
#  'HTBI',
#  'FRBK',
#  'FIZZ',
#  'FFKT',
#  'FCNCA',
#  'EBIO',
#  'BXE',
#  'BWXT',
#  'BMTC',
#  'BLKB',
#  'BBSI',
#  'BABY',
#  'OZRK',
#  'MBII',
#  'JBT',
#  'HDB',
#  'FBP',
#  'FBHS',
#  'EGBN',
#  'CBSH',
#  'CANF',
#  'BWP',
#  'BUSE',
#  'BURL',
#  'BRO',
#  'BRKL',
#  'BONT',
#  'BOJA',
#  'BKJ',
#  'BHB',
#  'BGG',
#  'BEAT',
#  'BCC',
#  'BANC',
#  'WASH',
#  'WABC',
#  'UCBI',
#  'PPBI',
#  'PLX',
#  'NBTB',
#  'INBK',
#  'IBP',
#  'EBR',
#  'CSFL',
#  'CSBK',
#  'CIB',
#  'CBU',
#  'CBLI',
#  'CATY',
#  'BWINB',
#  'BVN',
#  'BRN',
#  'BORN',
#  'BOFI',
#  'BLMN',
#  'BIOL',
#  'BBRG',
#  'WIFI',
#  'SJT',
#  'SBS',
#  'PFBI',
#  'PEBK',
#  'NX',
#  'LOB',
#  'KIN',
#  'IBCP',
#  'GWB',
#  'FARM',
#  'EBSB',
#  'CUDA',
#  'CCBG',
#  'CBF',
#  'CBD',
#  'BXMT',
#  'BTG',
#  'BOSC',
#  'BLMT',
#  'BLFS',
#  'BKEP',
#  'BFS',
#  'BFR',
#  'BF-B',
#  'BERY',
#  'BELFB',
#  'UBNK',
#  'TRST',
#  'TOWN',
#  'TBNK',
#  'SQBG',
#  'SPHS',
#  'SGBK',
#  'SBH',
#  'ORPN',
#  'NWBI',
#  'NKSH',
#  'NFBK',
#  'MNRO',
#  'LBAI',
#  'GRBK',
#  'GBT',
#  'FBNK',
#  'CZWI',
#  'CBPO',
#  'BSTC',
#  'BSRR',
#  'BSQR',
#  'BSFT',
#  'BRX',
#  'BPFH',
#  'BLX',
#  'BLDR',
#  'BIOS',
#  'BHLB',
#  'BDGE',
#  'BCOM',
#  'BANF',
#  'XELB',
#  'UBOH',
#  'TTOO',
#  'TRIB',
#  'SVA',
#  ...]

# %%
len(tickers)
# Out:
# 5359

# %%
categories=au_stocks['Category Name']
categories=np.unique(categories.tolist())
categories
# Out:
# array(['Accident & Health Insurance', 'Advertising Agencies',
#        'Aerospace/Defense - Major Diversified', 'Agricultural Chemicals',
#        'Air Delivery & Freight Services', 'Air Services, Other',
#        'Aluminum', 'Apparel Stores', 'Asset Management',
#        'Auto Dealerships', 'Auto Parts', 'Beverages - Brewers',
#        'Beverages - Soft Drinks', 'Beverages - Wineries & Distillers',
#        'Biotechnology', 'Broadcasting - Radio', 'Broadcasting - TV',
#        'Business Equipment', 'Business Services',
#        'Business Software & Services', 'Chemicals - Major Diversified',
#        'Communication Equipment', 'Computers Wholesale', 'Confectioners',
#        'Conglomerates', 'Copper', 'Credit Services',
#        'Data Storage Devices', 'Department Stores',
#        'Discount, Variety Stores', 'Diversified Electronics',
#        'Diversified Machinery', 'Diversified Utilities',
#        'Drug Manufacturers - Major', 'Drugs - Generic',
#        'Education & Training Services', 'Electric Utilities',
#        'Electronic Equipment', 'Electronics Wholesale',
#        'Entertainment - Diversified', 'Farm & Construction Machinery',
#        'Farm Products', 'Food - Major Diversified', 'Food Wholesale',
#        'Gaming Activities', 'Gas Utilities', 'General Building Materials',
#        'General Contractors', 'Gold', 'Grocery Stores',
#        'Health Care Plans', 'Healthcare Information Services',
#        'Heavy Construction', 'Home Furnishings & Fixtures', 'Hospitals',
#        'Independent Oil & Gas', 'Industrial Equipment Wholesale',
#        'Industrial Metals & Minerals', 'Information Technology Services',
#        'Insurance Brokers', 'Internet Information Providers',
#        'Investment Brokerage - National', 'Jewelry Stores',
#        'Life Insurance', 'Lodging', 'Long-Term Care Facilities',
#        'Lumber, Wood Production', 'Machine Tools & Accessories',
#        'Major Airlines', 'Major Integrated Oil & Gas',
#        'Marketing Services', 'Medical Appliances & Equipment',
#        'Medical Equipment Wholesale', 'Medical Instruments & Supplies',
#        'Medical Laboratories & Research', 'Metal Fabrication',
#        'Money Center Banks', 'Mortgage Investment',
#        'Multimedia & Graphics Software',
#        'Oil & Gas Drilling & Exploration',
#        'Oil & Gas Equipment & Services', 'Oil & Gas Pipelines',
#        'Oil & Gas Refining & Marketing', 'Packaging & Containers',
#        'Paper & Paper Products', 'Personal Products', 'Personal Services',
#        'Pollution & Treatment Controls', 'Property & Casualty Insurance',
#        'Property Management', 'Publishing - Newspapers',
#        'REIT - Diversified', 'REIT - Hotel/Motel', 'REIT - Industrial',
#        'REIT - Office', 'REIT - Residential', 'REIT - Retail',
#        'Railroads', 'Real Estate Development',
#        'Recreational Goods, Other', 'Recreational Vehicles',
#        'Rental & Leasing Services', 'Residential Construction',
#        'Resorts & Casinos', 'Restaurants', 'Rubber & Plastics',
#        'Savings & Loans', 'Scientific & Technical Instruments',
#        'Security & Protection Services', 'Semiconductor - Broad Line',
#        'Semiconductor Equipment & Materials',
#        'Semiconductor- Memory Chips', 'Shipping', 'Silver',
#        'Specialty Chemicals', 'Specialty Retail, Other',
#        'Staffing & Outsourcing Services', 'Steel & Iron',
#        'Technical & System Software', 'Textile - Apparel Clothing',
#        'Textile - Apparel Footwear & Accessories', 'Textile Industrial',
#        'Trucking', 'Trucks & Other Vehicles', 'Waste Management',
#        'Wireless Communications', 'nan'], dtype='<U40')

# %%
len(categories)
# Out:
# 127

# %%
p1,p2,t=[],[],''
print(p1,p2 ,t== [],[],'')
# Out:
# [] [] False []
