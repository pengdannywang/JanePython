# %%
# -*- coding: utf-8 -*-
import sys, getopt
import pandas as pd
from sarimaxModel import forcastStocks
from loadstocks import loadStocksByTickers
from loadstocks import loadAuBlankTickersFromYahooExcel
path='/Users/pengwang/PycharmProjects/JanePython/'
inputfile = path+'Yahoo.xlsx'
outputfile = path+'stocks.csv'
data=stocks.resample('MS').mean()
result=pd.DataFrame()
for ticker in data.columns:
    result[ticker]=forcastStocks(path+'parameters.csv',ticker,data[ticker])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-4f09c3594b85> in <module>
#       4 from sarimaxModel import forcastStocks
#       5 from loadstocks import loadStocksByTickers
# ----> 6 from loadstocks import loadAuBlankTickersFromYahooExcel
#       7 path='/Users/pengwang/Dropbox/finance/'
#       8 inputfile = path+'Yahoo.xlsx'
#
# ImportError: cannot import name 'loadAuBlankTickersFromYahooExcel' from 'loadstocks' (/Users/pengwang/PycharmProjects/JanePython/src/stockthread/loadstocks.py)

# %%
au_tickers=au_stocks[au_stocks['Category Name'].notna()][['Ticker','Category Name']]
au_tickers
# Out:
#           Ticker                       Category Name
# 35        BMH.AX          General Building Materials
# 58        BRK.AX               Independent Oil & Gas
# 176       MPX.AX                 Property Management
# 798       ICG.AX        Industrial Metals & Minerals
# 837       CLA.AX        Industrial Metals & Minerals
# 896     VELCP.AX                    Asset Management
# 909       ORG.AX          Major Integrated Oil & Gas
# 954       ANZ.AX                  Money Center Banks
# 972       XRF.AX               Diversified Machinery
# 973       WOW.AX                      Grocery Stores
# 975       WAT.AX                Electronic Equipment
# 985       QBE.AX       Property & Casualty Insurance
# 1009      BXB.AX                   Business Services
# 1010      BHP.AX        Industrial Metals & Minerals
# 1040      WRR.AX             Wireless Communications
# 1054      MQG.AX     Investment Brokerage - National
# 1058      MCX.AX                    Asset Management
# 1059      KTE.AX               Diversified Utilities
# 1063      IPT.AX        Industrial Metals & Minerals
# 1084      BMP.AX      Internet Information Providers
# 1125      WPL.AX               Independent Oil & Gas
# 1128      WHC.AX        Industrial Metals & Minerals
# 1129      WES.AX                      Grocery Stores
# 1135      VMS.AX                              Copper
# 1136      VKA.AX                                Gold
# 1137      UCW.AX       Education & Training Services
# 1138      TZL.AX         Technical & System Software
# 1141      TLS.AX             Wireless Communications
# 1144      SXL.AX         Entertainment - Diversified
# 1155      REA.AX      Internet Information Providers
# ...          ...                                 ...
# 103075    BRC.AX                           Hospitals
# 103147    CAE.AX                              Copper
# 103438    CAV.AX                              Copper
# 103512    CAT.AX  Scientific & Technical Instruments
# 103595    CHP.AX                    Asset Management
# 103603    CHR.AX     Air Delivery & Freight Services
# 103632    CHZ.AX                              Copper
# 103697    CHK.AX        Industrial Metals & Minerals
# 103941    CNJ.AX        Industrial Metals & Minerals
# 104276    GBX.AX        Industrial Metals & Minerals
# 104296    MEU.AX        Industrial Metals & Minerals
# 104607    GRR.AX        Industrial Metals & Minerals
# 104750    HOR.AX        Industrial Metals & Minerals
# 104776    INA.AX                  REIT - Residential
# 105138    MAI.AX                    Asset Management
# 105196    MEY.AX        Industrial Metals & Minerals
# 105330    MAT.AX        Industrial Metals & Minerals
# 105437    MEL.AX               Independent Oil & Gas
# 105441    4DS.AX         Semiconductor- Memory Chips
# 105518    TRM.AX                                Gold
# 105558    MYQ.AX         Technical & System Software
# 105560    MYO.AX         Technical & System Software
# 105783    PRO.AX         Technical & System Software
# 105814    REF.AX             Wireless Communications
# 105853    REY.AX        Industrial Metals & Minerals
# 105857    STA.AX        Industrial Metals & Minerals
# 106076    STL.AX                  Business Equipment
# 106152    TER.AX        Industrial Metals & Minerals
# 106219    TRY.AX        Industrial Metals & Minerals
# 106324    N1H.AX                 Mortgage Investment
#
# [1437 rows x 2 columns]

# %%
tickers =au_tickers.tolist()
len(tickers)
# Out:
# 709
