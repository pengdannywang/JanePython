# %%
# -*- coding: utf-8 -*-

import pandas as pd
import pandas_datareader.data as web   # Package and modules for importing data; this code may change depending on pandas version
import datetime
import numpy as np
import os
import random
from datetime import timedelta
import statsmodels.api as sm
# SARIMAX example
from statsmodels.tsa.statespace.sarimax import SARIMAX
import sys, getopt

path='/root/pythondev/JanePython/'
inputfile = path+'ASXListedCompanies.csv'
outputfile = 'stocks.csv'

path='/root/pythondev/JanePython/'
outputfile = 'stocks.csv'
savepath=path+outputfile
data=pd.read_csv(savepath,parse_dates=['Date'],index_col='Date')
data=data[[col for col in data.columns if pd.Series(data[col].values>1).sum()>30]]
data
# Out:
# /root/miniconda/lib/python3.6/site-packages/ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in greater
#               ONT.AX    TGP.AX    TOT.AX  3PL.AX  8EC.AX  A2B.AX    ABP.AX  \
# Date
# 2017-01-29  6.849535  0.793177  0.931513   0.890  1.0000     NaN  2.523161
# 2017-01-30  6.849535  0.806621  0.931513   0.950  1.0000     NaN  2.532172
# 2017-01-31  6.886018  0.788696  0.931513   0.935  0.9900     NaN  2.550195
# 2017-02-01  6.977223  0.806621  0.947710   0.935  1.0000     NaN  2.532172
# 2017-02-02  6.931621  0.779733  0.931513   0.930  1.0000     NaN  2.532172
# 2017-02-05  6.931621  0.779733  0.903165   0.930  1.0050     NaN  2.541183
# 2017-02-06  6.968102  0.784215  0.931513   0.945  1.0050     NaN  2.568217
# 2017-02-07  6.977223  0.779733  0.931513   0.940  1.0050     NaN  2.613274
# 2017-02-08  7.022826  0.784215  0.931513   0.950  1.0150     NaN  2.658330
# 2017-02-09  6.977223  0.793177  0.931513   0.940  1.0100     NaN  2.640307
# 2017-02-12  6.977223  0.788696  0.931513   0.990  1.0100     NaN  2.649319
# 2017-02-13  6.977223  0.784215  0.931513   0.980  1.0100     NaN  2.676353
# 2017-02-14  7.031946  0.784215  0.947710   0.950  1.0200     NaN  2.703387
# 2017-02-15  6.813053  0.784215  0.943665   0.940  1.0250     NaN  2.685364
# 2017-02-16  6.803933  0.784215  0.943665   0.950  1.0300     NaN  2.730420
# 2017-02-19  6.694486  0.779733  0.899111   0.950  1.0150     NaN  2.757454
# 2017-02-20  6.612401  0.784215  0.899111   0.930  1.0100     NaN  2.793499
# 2017-02-21  6.585039  0.784215  0.899111   0.950  1.0200     NaN  2.793499
# 2017-02-22  6.566798  0.779733  0.939612   0.990  1.0200     NaN  2.793499
# 2017-02-23  6.566798  0.779733  0.939612   1.040  1.0200     NaN  2.775477
# 2017-02-26  6.630642  0.779733  0.935558   0.990  1.0100     NaN  2.793499
# 2017-02-27  6.521195  0.784215  0.939612   1.000  1.1298     NaN  2.793499
# 2017-02-28  6.521195  0.779733  0.939612   0.990  1.0050     NaN  2.793499
# 2017-03-01  6.658004  0.775252  0.955808   0.980  1.0150     NaN  2.847567
# 2017-03-02  6.658004  0.775252  0.972014   0.970  1.1217     NaN  2.802510
# 2017-03-05  6.566798  0.784215  0.972014   0.945  1.1217     NaN  2.829545
# 2019-05-13  0.545000  2.130000  54.540001   3.340000  5.604443  7.850000
# 2019-05-14  0.550000  2.100000  53.750000   3.330000  5.613958  7.850000
# 2019-05-15  0.540000  2.110000  54.310001   3.280000  5.652019  7.850000
# 2019-05-16  0.535000  2.150000  60.150002   3.320000  5.735000  7.850000
# 2019-05-17  0.535000  2.150000  61.299999   3.300000  5.770000  7.850000
# 2019-05-20  0.545000  2.160000  59.400002   3.470000  5.780000  7.930000
# 2019-05-21  0.535000  2.120000  59.580002   3.430000  5.800000  7.930000
# 2019-05-22  0.530000  2.140000  59.209999   3.460000  5.790000  8.200000
# 2019-05-23  0.530000  2.110000  60.139999   3.410000  5.750000  8.200000
# 2019-05-24  0.535000  2.100000  59.689999   3.360000  5.720000  8.200000
# 2019-05-27  0.530000  2.110000  60.200001   3.350000  5.780000  8.200000
# 2019-05-28  0.550000  2.130000  61.070000   3.360000  5.780000  8.200000
#
#             Z1P.AX
# Date
# 2017-01-29   0.770
# 2017-01-30   0.780
# 2017-01-31   0.760
# 2017-02-01   0.775
# 2017-02-02   0.750
# 2017-02-05   0.745
# 2017-02-06   0.730
# 2017-02-07   0.730
# 2017-02-08   0.730
# 2017-02-09   0.745
# 2017-02-12   0.745
# 2017-02-13   0.750
# 2017-02-14   0.750
# 2017-02-15   0.750
# 2017-02-16   0.730
# 2017-02-19   0.720
# 2017-02-20   0.700
# 2017-02-21   0.735
# 2017-02-22   0.700
# 2017-02-23   0.735
# 2017-02-26   0.770
# 2017-02-27   0.790
# 2017-02-28   0.750
# 2017-03-01   0.735
# 2017-03-02   0.780
# 2017-03-05   0.755
# 2017-03-06   0.760
# 2017-03-07   0.760
# 2017-03-08   0.730
# 2017-03-09   0.700
# ...            ...
# 2019-04-12   2.400
# 2019-04-15   2.700
# 2019-04-16   2.500
# 2019-04-17   2.550
# 2019-04-18   2.390
# 2019-04-23   2.290
# 2019-04-24   2.490
# 2019-04-26   2.480
# 2019-04-29   2.890
# 2019-04-30   3.060
# 2019-05-01   3.420
# 2019-05-02   3.440
# 2019-05-03   3.500
# 2019-05-06   3.320
# 2019-05-07   3.500
# 2019-05-08   3.380
# 2019-05-09   3.300
# 2019-05-10   3.310
# 2019-05-13   3.330
# 2019-05-14   3.400
# 2019-05-15   3.390
# 2019-05-16   3.480
# 2019-05-17   3.520
# 2019-05-20   3.670
# 2019-05-21   3.880
# 2019-05-22   3.790
# 2019-05-23   3.720
# 2019-05-24   3.500
# 2019-05-27   3.440
# 2019-05-28   3.470
#
# [588 rows x 628 columns]

# %%
end = datetime.date.today()
savepath=path+outputfile
errorpath=path+'errors.csv'
#end =datetime.datetime(end.year,end.month,1).date()


errors=pd.DataFrame([],columns=['item'])
errorexists=os.path.isfile(errorpath)
print('exists error',errorexists)
if(errorexists):
    errors=pd.read_csv(errorpath,index_col=0)
exists = os.path.isfile(savepath)
print(savepath,'exists file',exists)
months=12
# Out:
# exists error True
# /root/pythondev/JanePython/stocks.csv exists file True

# %%
if exists:
    exist_ds=pd.read_csv(savepath,parse_dates=['Date'],index_col='Date')
ds =pd.DataFrame()
exist_ds=pd.DataFrame()
for item in scraped_tickers:
    try:
        if  len(errors)>0 and errors['item'].str.contains(item).any():
            print(item,'occured an exception before. skip this time.')
        else:
            if(exists and exist_ds.columns.contains(item)):
                start=exist_ds[item].index[-1].date()
                print(item,' exists and update between',start,end,start<end)
                res=None
                new_end=end-timedelta(days=1)
                if(start<new_end):
                    remains=web.DataReader(item,"yahoo",start,new_end)['Adj Close']              
                    res=exist_ds[item].combine_first(remains)
                else:
                    res=exist_ds[item]

                exist_ds[item] =res
                res=res.loc[~res.index.duplicated(keep='first')]
                ds[item]=res
            else:
                start=getStartDate(end,months).date()
                print(item,'is new and load from yahoo between',start,end,start<end)
                res=web.DataReader(item,"yahoo",start,end)['Adj Close']
                res=res.loc[~res.index.duplicated(keep='first')]
                ds[item]=res
                exist_ds[item] =res

    except Exception as e: 

        da=pd.DataFrame([item],columns=errors.columns)
        print(item,'write in errors.csv',e)
        if(not str(e).find('No data fetched for symbol')==-1):
            errors=errors.append(da,ignore_index=True)
        pass
if(exist_ds.isna().all().sum()>0):
    exist_ds[exist_ds.columns[exist_ds.isna().all()]].dropna(axis=1,inplace=True)
exist_ds.columns[exist_ds.isna().any()].any()
#savepath='/Users/pengwang/Dropbox/finance/ttest.csv'
errors.to_csv(errorpath)
exist_ds.to_csv(savepath)
# Out:
# MOQ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ONT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# 14D.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# 1ST.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# T3D.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# TGP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# TOT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# TDO.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# DDD.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# 3PL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# 4DS.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# 5GN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# 88E.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# 8CO.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# 8IH.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# 8EC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# 8VI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# 9SP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# NNW.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ACB.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AYI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# A2B.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ABP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ABL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AEG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ABT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AJC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AKG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AX8.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AX1.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ACS.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ACQ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ACF.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ACR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ACW.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AIV.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ADA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ADH.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# 1AD.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ADD.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AAU.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ABC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ADR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AHZ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ADY.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ADT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ADJ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ANO.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ABV.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ASW.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AV1.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ADX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AER.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AML.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AEI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AIS.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AEB.AX occured an exception before. skip this time.
# AFR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# A1G.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AFT.AX occured an exception before. skip this time.
# AFP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# APT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AGL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AGJ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AMN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AGR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AHL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# APW.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AGI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AIZ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AXP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AJL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AQG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AUQ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ACL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ALY.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ALC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AL8.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ARN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# LEP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AJX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AQI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AQX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ALK.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AHQ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AMT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AQZ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# A40.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AGS.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AGE.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AYR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# A4N.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ALQ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ARS.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AZI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ATC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ATH.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AIQ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# 1AG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AGH.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ALU.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AME.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AJM.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AWC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AMA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ANL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AYS.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AMO.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AMB.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AMH.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AMC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ABR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AOW.AX occured an exception before. skip this time.
# AMP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ATX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ANQ.AX occured an exception before. skip this time.
# ALT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ANR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ADN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ATM.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AS1.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AQM.AX occured an exception before. skip this time.
# AAR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AGG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AB1.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AWV.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ANN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ASN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ADO.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AZY.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# APL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ANP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# APE.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# APA.AX occured an exception before. skip this time.
# AHX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AQR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ADI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# APD.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AOP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AON.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AOJ.AX occured an exception before. skip this time.
# AOR.AX occured an exception before. skip this time.
# AOL.AX occured an exception before. skip this time.
# AO2.AX occured an exception before. skip this time.
# AO3.AX occured an exception before. skip this time.
# ATL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# APX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AD1.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AQS.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ARU.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ARB.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ARX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AXE.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AR9.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ARL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ALG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ADV.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ARF.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ARD.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AXT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ALI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ARG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ARE.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AGY.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ARA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ALL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AHK.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AJQ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AWN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ARQ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AMD.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ARV.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AAJ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AHY.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AJY.AX occured an exception before. skip this time.
# AFA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ASH.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AJJ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ATB.AX occured an exception before. skip this time.
# APZ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ASP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AKM.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AO1.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AIR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ARO.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ATR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ASX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ATA.AX occured an exception before. skip this time.
# AHN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ALX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ATP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AMS.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ATU.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AUB.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AIA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AVC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ACP.AX occured an exception before. skip this time.
# AD8.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AKP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AKN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AU8.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AEE.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AMI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AUR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AZJ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AOU.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ABW.AX occured an exception before. skip this time.
# AIB.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# A3D.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ARM.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AUP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ANW.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AC8.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ASL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AUC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AMG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AOA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ANV.AX occured an exception before. skip this time.
# AST.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AQD.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ASB.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AUL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AUH.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AOK.AX occured an exception before. skip this time.
# ANG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# APG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AGD.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ANZ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AYM.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AAC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AAP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ABX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# XCL.AX occured an exception before. skip this time.
# AHF.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AYF.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AEF.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AFG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AFI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AGM.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ALF.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AYK.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AYZ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AUZ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AN1.AX occured an exception before. skip this time.
# AQC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# API.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# APC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ARC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AUI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AYU.AX occured an exception before. skip this time.
# AOF.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AVL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AVG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AWY.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ATS.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ANS.AX occured an exception before. skip this time.
# ABA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AUT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AIY.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AHG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ASG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AVA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AEV.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AVN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AOG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AVW.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AVH.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AVJ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AVZ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AVQ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AXI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AXL.AX occured an exception before. skip this time.
# AYG.AX occured an exception before. skip this time.
# AZM.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AZT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AZT.AX write in errors.csv 'Date'
# AZV.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# AZS.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BBN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BPP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BTI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BOQ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BMN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BAP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BD1.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BDC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BAR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BST.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BSE.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BSM.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BAS.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BSR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BRL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BAT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BMH.AX occured an exception before. skip this time.
# BAU.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BBX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BCI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BPT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BLX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BCN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BCC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BGA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BFG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BAL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BGL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BEN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BLT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BHD.AX occured an exception before. skip this time.
# BEL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BKY.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BFC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BYI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BHP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BID.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BRI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BNL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BTH.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BIN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BGT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BNO.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BIT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BXN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BIR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BGS.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BIS.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BSN.AX occured an exception before. skip this time.
# BKI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BKM.AX occured an exception before. skip this time.
# BC8.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BDG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BKT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BSP.AX occured an exception before. skip this time.
# BEM.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BLK.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BKL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BSX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BWF.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BWR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BLZ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BGH.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BDI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BLU.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BLA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BAF.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BCT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BSL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BLG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BMG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BBC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BOA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BLY.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BDA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BAH.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BOL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BBR.AX occured an exception before. skip this time.
# BLD.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BOE.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BOT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BOC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# B2Y.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BUY.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BCB.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BHL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BPB.AX occured an exception before. skip this time.
# BPH.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BRN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BXB.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BVS.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BRB.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BRG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BKW.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BBL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BGP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BCK.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BPL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BGR.AX occured an exception before. skip this time.
# BEE.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BRK.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BYH.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BSA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BTC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BUB.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BUD.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BUG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BIQ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BNR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BCL.AX occured an exception before. skip this time.
# BRU.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BUX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BMP.AX occured an exception before. skip this time.
# BWP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BWX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BYE.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# BPG.AX occured an exception before. skip this time.
# CDM.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CAD.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# DXA.AX occured an exception before. skip this time.
# CAI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CE1.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CXL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CTX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CLB.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CGB.AX occured an exception before. skip this time.
# CAN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CAE.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CP1.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CBY.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CAY.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CFE.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CAG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CAJ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CAA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CRS.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CMM.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CAQ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CVV.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CWX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CRB.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CNX.AX occured an exception before. skip this time.
# CRM.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CG1.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CDX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CDV.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CDD.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CDP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CIN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CNB.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CVN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CAV.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CCE.AX occured an exception before. skip this time.
# CAP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CAR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CCV.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CWZ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CZI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CMD.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CCZ.AX occured an exception before. skip this time.
# CDT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CYL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CAT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CXU.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CAZ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CBC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CBL.AX occured an exception before. skip this time.
# CT1.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CWP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CNL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CDY.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CLT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CLA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CTM.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CTL.AX occured an exception before. skip this time.
# CTP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CAF.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CXM.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CNI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CIP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CMA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CVS.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CFO.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CHN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CEL.AX occured an exception before. skip this time.
# CGF.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CHJ.AX occured an exception before. skip this time.
# CHU.AX occured an exception before. skip this time.
# CHR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CIA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CCA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CWL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CQE.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CHC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CLW.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CQR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CML.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CHZ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CCB.AX occured an exception before. skip this time.
# CMC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CDH.AX occured an exception before. skip this time.
# CNU.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CII.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CIM.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CRO.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CNW.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CTO.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CCX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CVL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CLY.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CL1.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CLZ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CSS.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CLQ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CWY.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CVW.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CPV.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CDG.AX occured an exception before. skip this time.
# CAM.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CIW.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CUV.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CLV.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CGR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CA8.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# COB.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CCL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# COH.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CDA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CGS.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CHK.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CKA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# COL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CL8.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CLH.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CKF.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CRL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# COI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CBA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CCG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CMP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CPU.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CLF.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CNJ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CIO.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CXZ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# COG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CSD.AX occured an exception before. skip this time.
# CZL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CR1.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CEN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CGA.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CIE.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CVF.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CM1.AX occured an exception before. skip this time.
# COE.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# C6C.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CSE.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# COY.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CZN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CD1.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CD2.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CD3.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CXO.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CIZ.AX occured an exception before. skip this time.
# CRN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CTD.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# COO.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CGC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CGM.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CUP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CCJ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CVT.AX occured an exception before. skip this time.
# CYG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CZR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CGO.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CXX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CGN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CRD.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CCP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CI1.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CPH.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CMW.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CLI.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CUX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CM8.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CSK.AX occured an exception before. skip this time.
# CWN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CU1.AX occured an exception before. skip this time.
# CU2.AX occured an exception before. skip this time.
# CAS.AX occured an exception before. skip this time.
# CTE.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CSV.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CSL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CSR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CLX.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CDU.AX occured an exception before. skip this time.
# CUE.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CUL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CV1.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CVC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CYB.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CYQ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CYC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CY5.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# CYP.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# DCN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# DAU.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# DNK.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# DHR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# DTM.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# DTL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# DDT.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# DTR.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# DAV.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# DEG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# DEM.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# DCG.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# DYL.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# DLC.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# D13.AX occured an exception before. skip this time.
# DGH.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# DEV.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# DVN.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# DXS.AX is new and load from yahoo between 2017-01-29 2019-05-29 True

# %%
ticker='MOQ.AX'
start=getStartDate(end,months).date()
print(ticker,'is new and load from yahoo between',start,end,start<end)
res=web.DataReader(ticker,"yahoo",start,end)['Adj Close']
ds[ticker]=res
exist_ds[ticker] =res
res
# Out:
# MOQ.AX is new and load from yahoo between 2017-01-29 2019-05-29 True
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-c3eae91f8620> in <module>
#       3 print(ticker,'is new and load from yahoo between',start,end,start<end)
#       4 res=web.DataReader(ticker,"yahoo",start,end)['Adj Close']
# ----> 5 ds[ticker]=res
#       6 exist_ds[ticker] =res
#       7 res
#
# ~/miniconda/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~/miniconda/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# ~/miniconda/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3605
#    3606         if isinstance(value, Series):
# -> 3607             value = reindexer(value)
#    3608
#    3609         elif isinstance(value, DataFrame):
#
# ~/miniconda/lib/python3.6/site-packages/pandas/core/frame.py in reindexer(value)
#    3597                     # duplicate axis
#    3598                     if not value.index.is_unique:
# -> 3599                         raise e
#    3600
#    3601                     # other
#
# ~/miniconda/lib/python3.6/site-packages/pandas/core/frame.py in reindexer(value)
#    3592                 # GH 4107
#    3593                 try:
# -> 3594                     value = value.reindex(self.index)._values
#    3595                 except Exception as e:
#    3596
#
# ~/miniconda/lib/python3.6/site-packages/pandas/core/series.py in reindex(self, index, **kwargs)
#    3736     @Appender(generic.NDFrame.reindex.__doc__)
#    3737     def reindex(self, index=None, **kwargs):
# -> 3738         return super(Series, self).reindex(index=index, **kwargs)
#    3739
#    3740     def drop(self, labels=None, axis=0, index=None, columns=None,
#
# ~/miniconda/lib/python3.6/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4354         # perform the reindex on the axes
#    4355         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 4356                                   fill_value, copy).__finalize__(self)
#    4357
#    4358     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# ~/miniconda/lib/python3.6/site-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4372             obj = obj._reindex_with_indexers({axis: [new_index, indexer]},
#    4373                                              fill_value=fill_value,
# -> 4374                                              copy=copy, allow_dups=False)
#    4375
#    4376         return obj
#
# ~/miniconda/lib/python3.6/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4488                                                 fill_value=fill_value,
#    4489                                                 allow_dups=allow_dups,
# -> 4490                                                 copy=copy)
#    4491
#    4492         if copy and new_data is self._data:
#
# ~/miniconda/lib/python3.6/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1222         # some axes don't allow reindexing with dups
#    1223         if not allow_dups:
# -> 1224             self.axes[axis]._can_reindex(indexer)
#    1225
#    1226         if axis >= self.ndim:
#
# ~/miniconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in _can_reindex(self, indexer)
#    3085         # trying to reindex on an axis with duplicates
#    3086         if not self.is_unique and len(indexer):
# -> 3087             raise ValueError("cannot reindex from a duplicate axis")
#    3088
#    3089     def reindex(self, target, method=None, level=None, limit=None,
#
# ValueError: cannot reindex from a duplicate axis
