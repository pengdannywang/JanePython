# %%
# -*- coding: utf-8 -*-

import pandas as pd
import pandas_datareader.data as web   # Package and modules for importing data; this code may change depending on pandas version
import datetime
import numpy as np
import os
import random
from datetime import timedelta
import statsmodels.api as sm
import pandas_datareader.data as web
# SARIMAX example
from statsmodels.tsa.statespace.sarimax import SARIMAX
import sys, getopt
end = datetime.date.today()
months=18

day=end.day
year=end.year-months//12-1
month=months%12+1
start=datetime.datetime(year,month,day)
item='SMI.AX'
data=web.DataReader(item,"yahoo",start,end)['Adj Close'] 
data
# Out:
# Date
# 2017-07-11    0.02800
# 2017-07-12    0.02625
# 2017-07-13    0.03063
# 2017-07-14    0.03063
# 2017-07-17    0.02800
# 2017-07-18    0.03063
# 2017-07-19    0.02625
# 2017-07-20    0.02625
# 2017-07-21    0.02450
# 2017-07-24    0.02625
# 2017-07-25    0.02450
# 2017-07-26    0.02450
# 2017-07-27    0.02450
# 2017-07-28    0.02188
# 2017-07-31    0.02188
# 2017-08-01    0.02188
# 2017-08-02    0.02363
# 2017-08-03    0.02188
# 2017-08-04    0.02363
# 2017-08-07    0.02450
# 2017-08-08    0.02450
# 2017-08-09    0.02450
# 2017-08-10    0.02450
# 2017-08-11    0.02450
# 2017-08-14    0.02538
# 2017-08-15    0.02538
# 2017-08-16    0.02538
# 2017-08-17    0.02450
# 2017-08-18    0.02538
# 2017-08-21    0.03150
#                ...
# 2019-03-26    0.00400
# 2019-03-27    0.00500
# 2019-03-28    0.00500
# 2019-03-31    0.00400
# 2019-04-01    0.00400
# 2019-04-02    0.00500
# 2019-04-03    0.00400
# 2019-04-04    0.00400
# 2019-04-08    0.00400
# 2019-04-09    0.00400
# 2019-04-10    0.00400
# 2019-04-11    0.00400
# 2019-04-12    0.00400
# 2019-04-15    0.00400
# 2019-04-16    0.00400
# 2019-04-17    0.00300
# 2019-04-18    0.00300
# 2019-04-23    0.00300
# 2019-04-24    0.00300
# 2019-04-26    0.00300
# 2019-04-29    0.00300
# 2019-04-30    0.00300
# 2019-05-01    0.00300
# 2019-05-02    0.00300
# 2019-05-03    0.00300
# 2019-05-06    0.00300
# 2019-05-07    0.00300
# 2019-05-08    0.00300
# 2019-05-09    0.00300
# 2019-05-10    0.00300
# Name: Adj Close, Length: 464, dtype: float64
